# %%
import numpy as np
import pandas as pd
import math

# %%
CCLE_label_waterfall = pd.read_csv("D:/rws/PhamGpreprocess/Data/CCLE_label_total_drugs_binary.csv",index_col=0)
CCLE_label_waterfall
# Out:
#            X1.AZAKENPAULLONE X1.NAPHTHYL.PP1 X1.PHENYLBIGUANIDE  \
# ACH-001113         sensitive       sensitive          sensitive
# ACH-000242         resistant       resistant          sensitive
# ACH-000461         sensitive       sensitive          sensitive
# ACH-000528         resistant       sensitive          sensitive
# ACH-000792         resistant       resistant          resistant
# ...                      ...             ...                ...
# ACH-000968         resistant       sensitive          resistant
# ACH-000973         sensitive       sensitive          sensitive
# ACH-001128         resistant             NaN                NaN
# ACH-000750         sensitive       sensitive          sensitive
# ACH-000052         sensitive       sensitive          sensitive
#
#            X10.DEACETYLBACCATIN X10.HYDROXYCAMPTOTHECIN  \
# ACH-001113            sensitive               sensitive
# ACH-000242            sensitive               sensitive
# ...

# %%
GDSC_label_waterfall = pd.read_csv("D:/rws/PhamGpreprocess/Data/GDSC_label_total_drugs_binary.csv",index_col=0)
GDSC_label_waterfall
# Out:
#              X5.FLUOROURACIL     ABT737   AGI.5198   AGI.6780    AMG.319  \
# DATA.683665        resistant  sensitive  resistant  resistant  resistant
# DATA.683667        resistant  sensitive  resistant  resistant  resistant
# DATA.684052        resistant  sensitive  resistant  resistant  resistant
# DATA.684057        resistant        NaN        NaN  resistant        NaN
# DATA.684059        resistant  resistant  resistant  resistant  resistant
# ...                      ...        ...        ...        ...        ...
# DATA.1659928       resistant  resistant  resistant  resistant  resistant
# DATA.1660034       resistant  resistant  resistant  resistant        NaN
# DATA.1660035       resistant  resistant  resistant  resistant        NaN
# DATA.1660036       resistant        NaN        NaN  resistant        NaN
# DATA.1674021       resistant  resistant  resistant  resistant  resistant
#
#                 AT13148     AZ6102      AZ960    AZD1208    AZD1332  ...  \
# ...

# %%
CONC_wf_df = pd.concat([GDSC_label_waterfall,CCLE_label_waterfall])
CONC_wf_df.to_csv("data/TOTAL_label_binary_wf.csv")
CONC_wf_df
# Out:
#             X5.FLUOROURACIL     ABT737   AGI.5198   AGI.6780    AMG.319  \
# DATA.683665       resistant  sensitive  resistant  resistant  resistant
# DATA.683667       resistant  sensitive  resistant  resistant  resistant
# DATA.684052       resistant  sensitive  resistant  resistant  resistant
# DATA.684057       resistant        NaN        NaN  resistant        NaN
# DATA.684059       resistant  resistant  resistant  resistant  resistant
# ...                     ...        ...        ...        ...        ...
# ACH-000968        resistant        NaN        NaN        NaN        NaN
# ACH-000973        sensitive        NaN        NaN        NaN        NaN
# ACH-001128        sensitive        NaN        NaN        NaN        NaN
# ACH-000750        resistant        NaN        NaN        NaN        NaN
# ACH-000052              NaN        NaN        NaN        NaN        NaN
#
#                AT13148     AZ6102      AZ960    AZD1208    AZD1332  ...  \
# ...
